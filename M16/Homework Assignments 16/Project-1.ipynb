# %%
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Bestsellers with categories.csv")

# %%
data.head(5)

# %%
data.dtypes

# %%
data.isnull().sum()

# %%
mean_User_Rating = np.mean(data['User_Rating'])
print("Mean of User_Rating is : ", mean_User_Rating)

# %%
median_User_Rating = np.median(data['User_Rating'])
print("Median of User_Rating is : ", median_User_Rating)

# %%
mode_User_Rating = stats.mode(data['User_Rating'])
print("Mode of User_Rating is : ", mode_User_Rating)

# %%
mean_price = np.mean(data['Price'])
print("Mean of Price is : ", mean_price)

# %%
median_price = np.median(data['Price'])
print("Median of Price is : ", median_price)

# %%
mode_price = stats.mode(data['Price'])
print("Mode of The Price is : ", mode_price)

# %%
mean_reviews = np.mean(data['Reviews'])
print("Mean of Reviews is : ", mean_reviews)

# %%
median_reviews = np.median(data['Reviews'])
print("Median of Reviews is : ", median_reviews)

# %%
mode_reviews = stats.mode(data['Reviews'])
print("Mode of Reviews is : ", mode_reviews)
