# %%
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Titanic Dataset.csv")

# %%
data.head(5)

# %%
data.dtypes

# %%
data.isnull().sum()

# %%
median_age = np.median(data['Age'])
print("Median of Age is : ", median_age)

# %%
median_fare = np.median(data['Fare'])
print("Median of Fare is : ", median_fare)

# %%
mode_age = stats.mode(data['Age'])
print("Mode of Age is : ", mode_age)

# %%
mode_class = stats.mode(data['Pclass'])
print("Mode of PClass is : ", mode_class)

# %%
mean_age = np.mean(data['Age'])
print("Mean of Age is : ", mean_age)

# %%
mean_fare = np.mean(data['Fare'])
print("Mean of Fare is : ", mean_fare)

# %%
mode_gender = data['Gender'].value_counts().index[0]
print("Mode of the feature 'Gender' is : ", mode_gender)

# %%
mean_survived = np.mean(data['Survived'])
print("Mean of the Survived is: ", mean_survived)

# %%
median_survived = np.median(data['Survived'])
print("Median of the Survived is: ", median_survived)

# %%
mode_survived = stats.mode(data['Survived'])
print("Mode of The Survived is : ", mode_survived)

# %%
mode_embarked = data['Embarked'].value_counts().index[0]
print("Mode of the Embarked is: ", mode_embarked)
# Out:
# Mode of the Embarked is:  S
