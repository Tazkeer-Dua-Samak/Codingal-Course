# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Penguins Data.csv")
df.head(10)

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.isnull().any()
